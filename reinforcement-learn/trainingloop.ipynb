# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import math

BOARD_SIZE = 4
ACTIONS = [0, 1, 2, 3]  # up, down, left, right

# %% [markdown]
# # Game Environment
# Notes:
#
# 0 is empty cell\
# all tiles are displayed as $\log_2(\text{tile value})$ for readability

# %%
def add_tile(board):
    empty = list(zip(*np.where(board == 0)))
    if not empty:   # no empty cells
        return board
    y, x = random.choice(empty)
    board[y][x] = 1 if random.random() < 0.9 else 2
    return board

def move_right(board):
    new_board = np.zeros_like(board)
    reward = 0
    for row in range(BOARD_SIZE):
        tiles = board[row][board[row] != 0] # collect non-zero tiles
        merged = []
        skip = False
        for i in range(len(tiles)):
            if skip:
                skip = False
                continue
            if i + 1 < len(tiles) and tiles[i] == tiles[i+1]:
                merged.append(tiles[i] + 1)
                reward += 2 ** (tiles[i] + 1)  # calculate reward
                skip = True
            else:
                merged.append(tiles[i])
        new_board[row][:len(merged)] = merged
    return new_board, reward

def move(board, direction): 
    if direction == 0:  # up
        board = np.rot90(board, 1)
        new_board, reward = move_right(board)   #reuse this func to death bc im lazy lmao
        new_board = np.rot90(new_board, -1)
    elif direction == 1:  # down
        board = np.rot90(board, -1)
        new_board, reward = move_right(board)
        new_board = np.rot90(new_board)
    elif direction == 2:  # left
        new_board, reward = move_right(board)
    elif direction == 3:  # right
        board = np.fliplr(board)
        new_board, reward = move_right(board)
        new_board = np.fliplr(new_board)
    else:
        raise ValueError("Invalid direction")
    return new_board, reward

def is_game_over(board):
    for a in ACTIONS:
        new_board, _ = move(board, a)
        if not np.array_equal(new_board, board):
            return False
    return True

class Game2048Env:
    def reset(self):
        self.board = np.zeros((BOARD_SIZE, BOARD_SIZE), dtype=int)
        self.board = add_tile(add_tile(self.board))
        return self.get_state()

    def step(self, action):
        old_max_tile = np.max(self.board)
        old_board = self.board.copy()
        self.board, reward = move(self.board, action)
        changed = not np.array_equal(self.board, old_board)
        if changed: # only add a tile if the board changed
            self.board = add_tile(self.board)
        new_max_tile = np.max(self.board)
        reward = (new_max_tile > old_max_tile)  # reward for increasing max tile, small reward for merging
        done = is_game_over(self.board)
        return self.get_state(), reward, done

    def get_state(self):
        return self.board.flatten() / 17.0  # normalize log2(2^17), max tile

# %% [markdown]
# # Environment Testing
# for debugging purposes

# %%
env = Game2048Env()
state = env.reset()
print("Initial board:")
print(env.board)

done = False
total_reward = 0

while not done:
    print("\nCurrent board:")
    print(env.board)

    move_str = input("Enter move (w=up, s=down, a=left, d=right, q=quit): ")
    if move_str == 'q':
        break
    move_map = {'w': 0, 's': 1, 'a': 2, 'd': 3}
    if move_str not in move_map:
        print("Invalid input.")
        continue

    action = move_map[move_str]
    prev_max = np.max(env.board)
    state, reward, done = env.step(action)
    new_max = np.max(env.board)

    print(f"Action: {move_str.upper()} | Reward: {reward:.2f} | Max tile: {2 ** new_max}")
    total_reward += reward

print("\nGame Over.")
print("Final board:")
print(env.board)
print(f"Total reward: {total_reward:.2f}")

# %% [markdown]
# # DQN

# %%
class DQN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(16, 256), # 4x4 board flattened
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 4)   # 4 possible actions
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Training Loop

# %%
env = Game2048Env()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

policy_net = DQN().to(device)
target_net = DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=1e-4)
memory = deque(maxlen=200000)
BATCH_SIZE = 128    # batch size for training
GAMMA = 0.999    # discount factor for future rewards
EPSILON = 1.0   # exploration rate
EPSILON_DECAY = 0.9995   # decay rate for exploration
EPSILON_MIN = 0.05   # minimum exploration rate
TARGET_UPDATE = 10  # how often to update the target network

def sample_action(state):
    if random.random() < EPSILON:   #if smaller than the exploration rate, choose random action
        return random.choice(ACTIONS)
    with torch.no_grad():   # otherwise choose the action based on the policy network
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        q_values = policy_net(state_tensor)
        return q_values.argmax().item()

def optimize(): # training
    if len(memory) < BATCH_SIZE:    # not enough samples to train
        return
    batch = random.sample(memory, BATCH_SIZE)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(states).to(device)
    actions = torch.LongTensor(actions).to(device).unsqueeze(1)
    rewards = torch.FloatTensor(rewards).to(device).unsqueeze(1)
    next_states = torch.FloatTensor(next_states).to(device)
    dones = torch.BoolTensor(dones).to(device).unsqueeze(1)

    q_values = policy_net(states).gather(1, actions)
    next_q_values = target_net(next_states).max(1, keepdim=True)[0]
    target_q = rewards + GAMMA * next_q_values * (~dones)

    loss = nn.functional.mse_loss(q_values, target_q.detach())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Main Training

# %%
for i in range(10000):
    state = env.reset() #reset the game
    total_reward = 0
    for t in range(1000):   #start playing games
        action = sample_action(state)
        next_state, reward, done = env.step(action)
        memory.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        optimize()
        if done:
            break
    biggest_tile = np.max(env.board)
    EPSILON = max(EPSILON_MIN, EPSILON * EPSILON_DECAY)
    if i % TARGET_UPDATE == 0:  #update policy network
        target_net.load_state_dict(policy_net.state_dict())
    if i % 10 == 0:
        print(f"Episode {i}, Total reward: {total_reward:.2f}, Biggest tile: {biggest_tile}, Epsilon: {EPSILON:.2f}")
# Out:
# Episode 0, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.97
# Episode 10, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.96
# Episode 20, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.96
# Episode 30, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.95
# Episode 40, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.95
# Episode 50, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.94
# Episode 60, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.94
# Episode 70, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.93
# Episode 80, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.93
# Episode 90, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.92
# Episode 100, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.92
# Episode 110, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.91
# Episode 120, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.91
# Episode 130, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.90
# Episode 140, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.90
# Episode 150, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.90
# Episode 160, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.89
# Episode 170, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.89
# Episode 180, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.88
# Episode 190, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.88
# Episode 200, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.87
# Episode 210, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.87
# Episode 220, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.86
# Episode 230, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.86
# Episode 240, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.86
# Episode 250, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.85
# Episode 260, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.85
# Episode 270, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.84
# Episode 280, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.84
# Episode 290, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.83
# Episode 300, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.83
# Episode 310, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.83
# Episode 320, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.82
# Episode 330, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.82
# Episode 340, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.81
# Episode 350, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.81
# Episode 360, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.81
# Episode 370, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.80
# Episode 380, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.80
# Episode 390, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.79
# Episode 400, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.79
# Episode 410, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.79
# Episode 420, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.78
# Episode 430, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.78
# Episode 440, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.77
# Episode 450, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.77
# Episode 460, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.77
# Episode 470, Total reward: 6.00, Biggest tile: 7, Epsilon: 0
Total reward: 5.00, Biggest tile: 6, Epsilon: 0.10
# Episode 4640, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4650, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4660, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.09
# Episode 4670, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.09
# Episode 4680, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4690, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4700, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4710, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4720, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4730, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4740, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4750, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4760, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4770, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.09
# Episode 4780, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4790, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4800, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.09
# Episode 4810, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4820, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4830, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.09
# Episode 4840, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4850, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.09
# Episode 4860, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4870, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.08
# Episode 4880, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4890, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4900, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4910, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4920, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4930, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4940, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4950, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.08
# Episode 4960, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 4970, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 4980, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.08
# Episode 4990, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 5000, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 5010, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 5020, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 5030, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 5040, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 5050, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.08
# Episode 5060, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 5070, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.08
# Episode 5080, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 5090, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.08
# Episode 5100, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.08
# Episode 5110, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5120, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5130, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5140, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5150, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5160, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5170, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5180, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5190, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5200, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5210, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5220, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.07
# Episode 5230, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5240, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5250, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5260, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5270, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5280, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5290, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5300, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5310, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5320, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5330, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5340, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5350, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.07
# Episode 5360, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.07
# Episode 5370, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5380, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.07
# Episode 5390, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.07
# Episode 5400, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.06
# Episode 5410, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5420, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5430, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5440, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5450, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5460, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5470, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5480, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5490, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5500, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5510, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5520, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5530, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5540, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5550, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5560, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5570, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5580, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5590, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5600, Total reward: 6.00, Biggest tile: 8, Epsilon: 0.06
# Episode 5610, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5620, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5630, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5640, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5650, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5660, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5670, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.06
# Episode 5680, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.06
# Episode 5690, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5700, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.06
# Episode 5710, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.06
# Episode 5720, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.06
# Episode 5730, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 5740, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 5750, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 5760, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 5770, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5780, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 5790, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5800, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5810, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 5820, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 5830, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5840, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5850, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 5860, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5870, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5880, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5890, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 5900, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 5910, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 5920, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5930, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5940, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5950, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5960, Total reward: 6.00, Biggest tile: 8, Epsilon: 0.05
# Episode 5970, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5980, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 5990, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6000, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6010, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6020, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6030, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6040, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6050, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6060, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6070, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6080, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6090, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6100, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6110, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6120, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6130, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6140, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6150, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 6160, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6170, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6180, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6190, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6200, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6210, Total reward: 6.00, Biggest tile: 8, Epsilon: 0.05
# Episode 6220, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6230, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6240, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6250, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6260, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6270, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6280, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6290, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 6300, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6310, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6320, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6330, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6340, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6350, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6360, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6370, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6380, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6390, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6400, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6410, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6420, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6430, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6440, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6450, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6460, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6470, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6480, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6490, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6500, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6510, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6520, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6530, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6540, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6550, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6560, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6570, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6580, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6590, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6600, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6610, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6620, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6630, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6640, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6650, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6660, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6670, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6680, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6690, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6700, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6710, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6720, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6730, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6740, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6750, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6760, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6770, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6780, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6790, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6800, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6810, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6820, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6830, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6840, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6850, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6860, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6870, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6880, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6890, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6900, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6910, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6920, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6930, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 6940, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 6950, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6960, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6970, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 6980, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 6990, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7000, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7010, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7020, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7030, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7040, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7050, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7060, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7070, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7080, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7090, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7100, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7110, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7120, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7130, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7140, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 7150, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7160, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7170, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7180, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7190, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7200, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7210, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7220, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7230, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7240, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7250, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7260, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7270, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7280, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7290, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7300, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7310, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7320, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7330, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7340, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7350, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7360, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7370, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7380, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7390, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# ...
# Episode 7540, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7550, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7560, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7570, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7580, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7590, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7600, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7610, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7620, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7630, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7640, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7650, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7660, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7670, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7680, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7690, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7700, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7710, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7720, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7730, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7740, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7750, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7760, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7770, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7780, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7790, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7800, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7810, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7820, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7830, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7840, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7850, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7860, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 7870, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7880, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7890, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7900, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7910, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7920, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 7930, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7940, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7950, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7960, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7970, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 7980, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 7990, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8000, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8010, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8020, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8030, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8040, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8050, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8060, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8070, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8080, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8090, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8100, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8110, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8120, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8130, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8140, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8150, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8160, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8170, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8180, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8190, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8200, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8210, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8220, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8230, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8240, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8250, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8260, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8270, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8280, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8290, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8300, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8310, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8320, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8330, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8340, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8350, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8360, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8370, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8380, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8390, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8400, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8410, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8420, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8430, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8440, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8450, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8460, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8470, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8480, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8490, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8500, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8510, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8520, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8530, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8540, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8550, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8560, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8570, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8580, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8590, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8600, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 8610, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8620, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8630, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8640, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8650, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8660, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8670, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8680, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8690, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8700, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8710, Total reward: 3.00, Biggest tile: 4, Epsilon: 0.05
# Episode 8720, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8730, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8740, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8750, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8760, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8770, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8780, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8790, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8800, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8810, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8820, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8830, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8840, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8850, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8860, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8870, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8880, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8890, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8900, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8910, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 8920, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8930, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8940, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8950, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8960, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8970, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 8980, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 8990, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9000, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9010, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9020, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9030, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9040, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9050, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9060, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9070, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9080, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9090, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9100, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9110, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9120, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9130, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9140, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9150, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9160, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9170, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9180, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9190, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9200, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9210, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9220, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9230, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9240, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9250, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9260, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9270, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9280, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9290, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9300, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9310, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9320, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9330, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9340, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9350, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9360, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9370, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9380, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9390, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9400, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9410, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9420, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9430, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9440, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9450, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9460, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9470, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9480, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9490, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9500, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9510, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9520, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9530, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9540, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9550, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9560, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9570, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9580, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9590, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9600, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9610, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9620, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9630, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9640, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9650, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9660, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9670, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9680, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9690, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9700, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9710, Total reward: 5.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9720, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9730, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9740, Total reward: 7.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9750, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9760, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9770, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9780, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9790, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9800, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9810, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9820, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9830, Total reward: 4.00, Biggest tile: 5, Epsilon: 0.05
# Episode 9840, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9850, Total reward: 6.00, Biggest tile: 8, Epsilon: 0.05
# Episode 9860, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9870, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9880, Total reward: 4.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9890, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9900, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9910, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9920, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9930, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9940, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9950, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9960, Total reward: 5.00, Biggest tile: 6, Epsilon: 0.05
# Episode 9970, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9980, Total reward: 6.00, Biggest tile: 7, Epsilon: 0.05
# Episode 9990, Total reward: 3.00, Biggest tile: 5, Epsilon: 0.05

# %% [markdown]
# # Export to ONNX

# %%
import onnx
dummy_input = torch.randn(1, 16).to(device)  # 4x4 flattened
torch.onnx.export(policy_net, dummy_input, "2048_ai.onnx", input_names=["input"], output_names=["output"])

# %% [markdown]
# # Convert ONNX to Tensorflow
#
# the package versions need to be really specific or else it crashes and burns
#
# make a new virtual env with the following:\
# `python3.10 -m venv tfenv`
#
# then install these versions:\
# `pip install tensorflow==2.13.0 keras==2.13.1`\
# `pip install onnx==1.14.0 onnx-tf==1.10.0 protobuf==3.20.3`\
# `pip install tensorflow-probability==0.20.0`
#
# then run this bash script:\
# `onnx-tf convert -i 2048_rl.onnx -o 2048_rl_tf`
